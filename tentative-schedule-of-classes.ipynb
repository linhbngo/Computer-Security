# %% [markdown]
# ### Part I: Introduction
#
# #### Week 1
# - Tue, Aug 28, 2018
#     - Overview of course syllabus
#     - Introduction of computer security
#
# - Thu, Aug 30, 2018
#     - Introduction to SEED platform
#     - Linux reviews
#
# ### Part II: Software Security
#
# #### Week 2
# - Tue, Sep 04, 2018
#     - Last Day of Add/Drop
#     - Set-UID Programs
# - Thu, Sep 06, 2018ping
#     - Set-UID Programs
#
# #### Week 3
# - Tue, Sep 11, 2018
#     - Environment Variables
# - Thu, Sep 13, 2018
#     - Environment Variables
#     - Environment Variable and Set-UID Lab (take-home)
#
# #### Week 4
# - Tue, Sep 18, 2018
#     - Program Memory Layout
# - Thu, Sep 20, 2018
#     - Program Memory Layout
#     - Buffer Overflow Lab
#
# #### Week 5
# - Tue, Sep 25, 2018
#     - Buffer Overflow Lab
# - Thu, Sep 27, 2018
#     - Return-to-libc Attack
# #### Week 6
# - Tue, Oct 02, 2018
#     - Return-to-libc Attack Lab
# - Thu, Oct 04, 2018
#     - Return-to-libc Attack Lab
#
# ### Part III: Web Security
#
# #### Week 7
# - Tue, Oct 09, 2018
#     - Exam 1
# - Thu, Oct 11, 2018
#     - Cross Site Request Forgery
#
# #### Week 8
# - Tue, Oct 16, 2018
#     - Cross Site Request Forgery
# - Thu, Oct 18, 2018
#     - Database in Web Application
#
# #### Week 9
# - Tue, Oct 23, 2018
#     - Database in Web Application
# Last Day of Course Withdrawal
# - Thu, Oct 25, 2018
#     - SQL Injection Attack Lab
#
# ### Part IV: Network Security
#
# #### Week 10
# - Tue, Oct 30, 2018
#     - Packet Sniffing and Spoofing
# - Thu, Nov 01, 2018
#     - Packet Sniffing and Spoofing
#
# #### Week 11
# - Tue, Nov 06, 2018
#     - Attaks on the TCP Protocols
# - Thu, Nov 08, 2018
#     - Firewall
#
# #### Week 12
# - Tue, Nov 13, 2018
#     - Lab TBD
# - Thu, Nov 15, 2018
#     - Lab TBD
#
# #### Week 13
# - Tue, Nov 20, 2018
# Reading/Writing Day
# - Thu, Nov 22, 2018
# Fall/Thanksgiving Break
#
# ### Part V: Cryptography
#
# #### Week 14
# - Tue, Nov 27, 2018
# - Thu, Nov 29, 2018
#
# #### Week 15
# - Tue, Dec 04, 2018
# - Thu, Dec 06, 2018
